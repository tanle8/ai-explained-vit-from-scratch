# %%
from utils import visualize_images, visualize_attention, load_experiment
import matplotlib.pyplot as plt

# %%
# Show some training images
visualize_images()

# %%
# Load Experiment
config, model, train_losses, test_losses, accuracies = load_experiment("vit_bs256_ep100_mps_1")

# %%
# Create subplots for losses and accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Train & Test Loss
ax1.plot(train_losses, label="Train loss")
ax1.plot(test_losses, label="Test loss")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss")
ax1.legend()

# Accuracy
ax2.plot(accuracies)
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Accuracy")

plt.savefig("metrics.png")
plt.show()

# %%
visualize_attention(model, "attention.png")
# Out:
# Using device for attention visualization: mps
# /Users/tanle/Source/ai/learn/archs/vision_transformers/vit-from-scratch/.venv/lib/python3.11/site-packages/torchvision/transforms/functional.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:209.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# Saved attention visualization to: attention.png

# %% [markdown]
# ## Conclusion
#
# The training process hit early stopping at epoch 67th. We have the run summary like following:
# - accuracy: 0.7309
# - epoch: 67
# - test_loss: 0.77762
# - train_loss: 0.6534
#
# Combine with losses plots and attention maps we can see our small, simplified ViT model can achieve quite good result on CIFAR-10. From the attention map, we can see the model has the ability to attend on relevant features of an object and be able to distinguish between object and background.
